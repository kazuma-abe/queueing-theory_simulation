# %% [markdown]
# <a href="https://colab.research.google.com/github/qriovider/queueing_theory/blob/main/preemptive_2type_jobs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.0.1-py2.py3-none-any.whl (29 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.0.1

# %%
import simpy
import numpy as np
import matplotlib.pyplot as plt

# %%
LAMBDA_1 = 2
LAMBDA_2 = 1
MU_1 = 4
MU_2 = 3

def generate_interarrival(LAMBDA):
  return np.random.exponential(1./LAMBDA)

def generate_service(MU):
  return np.random.exponential(1./MU)

def arriving_1(env, resource):
  i = 0
  while True:
    i = i + 1
    job1 = Job1(name="Job1-{}".format(i))
    yield env.timeout(generate_interarrival(LAMBDA_1))
    print(env.now, job1.name, 'arrives')
    env.process(job1.resource_user_1(env, i, resource))

def arriving_2(env, resource):
  i = 0
  while True:
    i = i + 1
    job2 = Job2(name="Job2-{}".format(i))
    yield env.timeout(generate_interarrival(LAMBDA_2))
    print(env.now, job2.name, 'arrives')
    env.process(job2.resource_user_2(env, i, resource))


class Job1(object):
  def __init__(self, name):
    self.name = name

  def resource_user_1(self, env, i, resource):
    with resource.request(priority=1) as req:
      yield req
      print(env.now, self.name, 'is being served')
      print('The number of using resources is', resource.count)
      yield env.timeout(generate_service(MU_1))
      print(env.now, self.name, 'leaves')

class Job2(object):
  def __init__(self, name):
    self.name = name
  
  def resource_user_2(self, env, i, resource):
    with resource.request(priority=2) as req:
      try:
        yield req
        print('The number of using resources is', resource.count)
        print(env.now, self.name, 'is being served')
        yield env.timeout(generate_service(MU_2))
        print(env.now, self.name, 'leaves')
      except simpy.Interrupt as interrupt:  
        print(env.now, self.name, 'got preempted')

# %%
env = simpy.Environment()
resource = simpy.PreemptiveResource(env, capacity=2)
env.process(arriving_1(env, resource))
env.process(arriving_2(env, resource))
env.run(until=50)
# Out:
# 0.006025114949002309 Job1-1 arrives
# 0.006025114949002309 Job1-1 is being served
# The number of using resources is 1
# 0.03569920720807038 Job1-1 leaves
# 0.17851745808065358 Job1-2 arrives
# 0.17851745808065358 Job1-2 is being served
# The number of using resources is 1
# 0.21170394101904771 Job1-2 leaves
# 0.6442622454438245 Job2-1 arrives
# The number of using resources is 1
# 0.6442622454438245 Job2-1 is being served
# 0.9246984154955897 Job2-2 arrives
# The number of using resources is 2
# 0.9246984154955897 Job2-2 is being served
# 1.1210314729551734 Job2-2 leaves
# 1.6768808036849658 Job1-3 arrives
# 1.6768808036849658 Job1-3 is being served
# The number of using resources is 2
# 1.7493896889758371 Job2-1 leaves
# 2.0087200249898918 Job1-3 leaves
# 2.226446134942936 Job1-4 arrives
# 2.226446134942936 Job1-4 is being served
# The number of using resources is 1
# 2.3517283955348627 Job1-5 arrives
# 2.3517283955348627 Job1-5 is being served
# The number of using resources is 2
# 2.5887446003829693 Job1-4 leaves
# 2.625589119387119 Job1-5 leaves
# 2.8198717379410194 Job1-6 arrives
# 2.8198717379410194 Job1-6 is being served
# The number of using resources is 1
# 2.906419302396552 Job1-7 arrives
# 2.906419302396552 Job1-7 is being served
# The number of using resources is 2
# 2.9485279595710736 Job1-7 leaves
# 3.2156813519425063 Job1-6 leaves
# 3.2874207198881793 Job2-3 arrives
# The number of using resources is 1
# 3.2874207198881793 Job2-3 is being served
# 3.4614056008687104 Job2-4 arrives
# The number of using resources is 2
# 3.4614056008687104 Job2-4 is being served
# 3.6918498468929366 Job1-8 arrives
# 3.6918498468929366 Job2-4 got preempted
# 3.6918498468929366 Job1-8 is being served
# The number of using resources is 2
# 3.7946774681529454 Job2-3 leaves
# 3.853089910670176 Job1-8 leaves
# 3.8769789984601792 Job2-5 arrives
# The number of using resources is 1
# 3.8769789984601792 Job2-5 is being served
# 4.040694332406132 Job2-5 leaves
# 4.268006146436199 Job1-9 arrives
# 4.268006146436199 Job1-9 is being served
# The number of using resources is 1
# 4.297103983965107 Job1-9 leaves
# 4.5162306919050454 Job1-10 arrives
# 4.5162306919050454 Job1-10 is being served
# The number of using resources is 1
# 4.636041660657872 Job1-10 leaves
# 6.2749613462147655 Job1-11 arrives
# 6.2749613462147655 Job1-11 is being served
# The number of using resources is 1
# 6.427400450379006 Job1-11 leaves
# 6.791577430775631 Job1-12 arrives
# 6.791577430775631 Job1-12 is being served
# The number of using resources is 1
# 6.85162806092546 Job1-12 leaves
# 6.971720902784528 Job1-13 arrives
# 6.971720902784528 Job1-13 is being served
# The number of using resources is 1
# 6.982908293149291 Job1-13 leaves
# 8.99105248161947 Job1-14 arrives
# 8.99105248161947 Job1-14 is being served
# The number of using resources is 1
# 9.008320790827515 Job1-14 leaves
# 10.114194286173202 Job1-15 arrives
# 10.114194286173202 Job1-15 is being served
# The number of using resources is 1
# 10.227596284324715 Job1-16 arrives
# 10.227596284324715 Job1-16 is being served
# The number of using resources is 2
# 10.288643449099679 Job1-16 leaves
# 10.440777660245713 Job1-17 arrives
# 10.440777660245713 Job1-17 is being served
# The number of using resources is 2
# 10.672910856296575 Job1-15 leaves
# 10.751801417739568 Job1-17 leaves
# 11.100278027036763 Job1-18 arrives
# 11.100278027036763 Job1-18 is being served
# The number of using resources is 1
# 11.181117526861696 Job2-6 arrives
# The number of using resources is 2
# 11.181117526861696 Job2-6 is being served
# 11.270909073717513 Job1-18 leaves
# 11.350800415769992 Job1-19 arrives
# 11.350800415769992 Job1-19 is being served
# The number of using resources is 2
# 11.381615465437706 Job2-7 arrives
# 11.603966320475159 Job2-8 arrives
# 11.608279958447918 Job2-6 leaves
# The number of using resources is 2
# 11.608279958447918 Job2-7 is being served
# 11.721725760710312 Job2-7 leaves
# The number of using resources is 2
# 11.721725760710312 Job2-8 is being served
# 11.7907408713151 Job1-19 leaves
# 12.039650985612242 Job1-20 arrives
# 12.039650985612242 Job1-20 is being served
# The number of using resources is 2
# 12.074912671720494 Job1-20 leaves
# 12.234933538339767 Job2-9 arrives
# The number of using resources is 2
# 12.234933538339767 Job2-9 is being served
# 12.322117230178472 Job1-21 arrives
# 12.322117230178472 Job2-9 got preempted
# 12.322117230178472 Job1-21 is being served
# The number of using resources is 2
# 12.587236519438687 Job2-8 leaves
# 12.591469165663952 Job1-21 leaves
# 12.633536759433056 Job1-22 arrives
# 12.633536759433056 Job1-22 is being served
# The number of using resources is 1
# 12.63890988473266 Job1-23 arrives
# 12.63890988473266 Job1-23 is being served
# The number of using resources is 2
# 12.666643181704117 Job1-22 leaves
# 12.820411617001396 Job1-24 arrives
# 12.820411617001396 Job1-24 is being served
# The number of using resources is 2
# 12.957266505256367 Job1-23 leaves
# 12.975459030722599 Job1-24 leaves
# 13.28533585798779 Job2-10 arrives
# The number of using resources is 1
# 13.28533585798779 Job2-10 is being served
# 13.321279630024389 Job1-25 arrives
# 13.321279630024389 Job1-25 is being served
# The number of using resources is 2
# 14.276272453888748 Job1-25 leaves
# 14.386099181731598 Job1-26 arrives
# 14.386099181731598 Job1-26 is being served
# The number of using resources is 2
# 14.419097722638597 Job2-10 leaves
# 14.445263604161665 Job1-26 leaves
# 14.66484702050141 Job1-27 arrives
# 14.66484702050141 Job1-27 is being served
# The number of using resources is 1
# 14.696843508393536 Job1-28 arrives
# 14.696843508393536 Job1-28 is being served
# The number of using resources is 2
# 14.71732518335236 Job1-27 leaves
# 14.914859953076089 Job1-28 leaves
# 15.266064713829168 Job1-29 arrives
# 15.266064713829168 Job1-29 is being served
# The number of using resources is 1
# 15.35011572887476 Job1-29 leaves
# 15.538765695222649 Job1-30 arrives
# 15.538765695222649 Job1-30 is being served
# The number of using resources is 1
# 15.596176416130875 Job1-30 leaves
# 16.03844916799793 Job1-31 arrives
# 16.03844916799793 Job1-31 is being served
# The number of using resources is 1
# 16.066677384265322 Job1-31 leaves
# 16.33176976203074 Job1-32 arrives
# 16.33176976203074 Job1-32 is being served
# The number of using resources is 1
# 16.64540260105291 Job1-33 arrives
# 16.64540260105291 Job1-33 is being served
# The number of using resources is 2
# 16.986130289629852 Job1-32 leaves
# 17.116534226532394 Job2-11 arrives
# The number of using resources is 2
# 17.116534226532394 Job2-11 is being served
# 17.154264865817176 Job1-34 arrives
# 17.154264865817176 Job2-11 got preempted
# 17.154264865817176 Job1-34 is being served
# The number of using resources is 2
# 17.400633737690203 Job1-35 arrives
# 17.474179779309704 Job1-34 leaves
# 17.474179779309704 Job1-35 is being served
# The number of using resources is 2
# 17.512288311322052 Job1-36 arrives
# 17.532297543008404 Job1-33 leaves
# 17.532297543008404 Job1-36 is being served
# The number of using resources is 2
# 17.53808227594201 Job2-12 arrives
# 17.583126595210775 Job1-35 leaves
# The number of using resources is 2
# 17.583126595210775 Job2-12 is being served
# 17.750697233603777 Job1-36 leaves
# 17.962744834215005 Job1-37 arrives
# 17.962744834215005 Job1-37 is being served
# The number of using resources is 2
# 17.96986974921639 Job1-38 arrives
# 17.96986974921639 Job2-12 got preempted
# 17.96986974921639 Job1-38 is being served
# The number of using resources is 2
# 18.124355996522688 Job1-37 leaves
# 18.619348649926888 Job1-39 arrives
# 18.619348649926888 Job1-39 is being served
# The number of using resources is 2
# 18.65598587241471 Job1-40 arrives
# 18.68122948165709 Job1-41 arrives
# 18.695399211170795 Job1-39 leaves
# 18.695399211170795 Job1-40 is being served
# The number of using resources is 2
# 18.907276780199954 Job1-42 arrives
# 18.958628958847893 Job1-43 arrives
# 18.98302775683444 Job1-40 leaves
# 18.98302775683444 Job1-41 is being served
# The number of using resources is 2
# 19.06997631318747 Job1-44 arrives
# 19.17472400191993 Job1-41 leaves
# 19.17472400191993 Job1-42 is being served
# The number of using resources is 2
# 19.202699681626743 Job1-42 leaves
# 19.202699681626743 Job1-43 is being served
# The number of using resources is 2
# 19.30461307794939 Job1-43 leaves
# 19.30461307794939 Job1-44 is being served
# The number of using resources is 2
# 19.33349016172196 Job1-38 leaves
# 19.44413691276768 Job1-44 leaves
# 19.498648470821344 Job2-13 arrives
# The number of using resources is 1
# 19.498648470821344 Job2-13 is being served
# 19.534231032435912 Job2-13 leaves
# 20.300827064301043 Job1-45 arrives
# 20.300827064301043 Job1-45 is being served
# The number of using resources is 1
# 20.38135656023811 Job1-45 leaves
# 20.47418905689381 Job1-46 arrives
# 20.47418905689381 Job1-46 is being served
# The number of using resources is 1
# 20.52702874258561 Job1-47 arrives
# 20.52702874258561 Job1-47 is being served
# The number of using resources is 2
# 20.532076025160087 Job1-47 leaves
# 20.711979251553768 Job1-46 leaves
# 20.98986038990784 Job1-48 arrives
# 20.98986038990784 Job1-48 is being served
# The number of using resources is 1
# 21.03816747966766 Job1-48 leaves
# 21.324132388254885 Job2-14 arrives
# The number of using resources is 1
# 21.324132388254885 Job2-14 is being served
# 21.352820088983247 Job1-49 arrives
# 21.352820088983247 Job1-49 is being served
# The number of using resources is 2
# 21.37953062718154 Job2-15 arrives
# 21.500909412585063 Job1-49 leaves
# The number of using resources is 2
# 21.500909412585063 Job2-15 is being served
# 21.521734260718812 Job2-14 leaves
# 21.678264499270803 Job2-15 leaves
# 22.07884981783304 Job2-16 arrives
# The number of using resources is 1
# 22.07884981783304 Job2-16 is being served
# 22.172796274031683 Job2-16 leaves
# 22.663528344443506 Job2-17 arrives
# The number of using resources is 1
# 22.663528344443506 Job2-17 is being served
# 22.859938911487877 Job1-50 arrives
# 22.859938911487877 Job1-50 is being served
# The number of using resources is 2
# 23.06422519345408 Job1-50 leaves
# 23.5331239806 Job1-51 arrives
# 23.5331239806 Job1-51 is being served
# The number of using resources is 2
# 23.650756303814127 Job2-17 leaves
# 23.976327630833705 Job1-51 leaves
# 24.430019182192307 Job2-18 arrives
# The number of using resources is 1
# 24.430019182192307 Job2-18 is being served
# 24.582853601320135 Job1-52 arrives
# 24.582853601320135 Job1-52 is being served
# The number of using resources is 2
# 24.62925696708053 Job1-52 leaves
# 24.74448435071624 Job1-53 arrives
# 24.74448435071624 Job1-53 is being served
# The number of using resources is 2
# 24.787098327675302 Job1-53 leaves
# 25.119200948056136 Job2-18 leaves
# 25.187964540907828 Job1-54 arrives
# 25.187964540907828 Job1-54 is being served
# The number of using resources is 1
# 25.738108231853385 Job1-54 leaves
# 25.785375845993578 Job1-55 arrives
# 25.785375845993578 Job1-55 is being served
# The number of using resources is 1
# 25.82858410268506 Job1-55 leaves
# 26.28456097515902 Job2-19 arrives
# The number of using resources is 1
# 26.28456097515902 Job2-19 is being served
# 26.310162279997765 Job1-56 arrives
# 26.310162279997765 Job1-56 is being served
# The number of using resources is 2
# 26.352268398649898 Job1-57 arrives
# 26.352268398649898 Job2-19 got preempted
# 26.352268398649898 Job1-57 is being served
# The number of using resources is 2
# 26.399293267662166 Job1-58 arrives
# 26.416876760926527 Job1-59 arrives
# 26.42382800538728 Job1-60 arrives
# 26.47161609975658 Job1-61 arrives
# 26.529972795866446 Job1-56 leaves
# 26.529972795866446 Job1-58 is being served
# The number of using resources is 2
# 26.53436488584127 Job1-62 arrives
# 26.541067205765493 Job1-58 leaves
# 26.541067205765493 Job1-59 is being served
# The number of using resources is 2
# 26.630262268874294 Job1-63 arrives
# 26.767339790267496 Job1-59 leaves
# 26.767339790267496 Job1-60 is being served
# The number of using resources is 2
# 26.81860104655518 Job1-60 leaves
# 26.81860104655518 Job1-61 is being served
# The number of using resources is 2
# 26.873913176121153 Job1-61 leaves
# 26.873913176121153 Job1-62 is being served
# The number of using resources is 2
# 27.007880892177837 Job1-57 leaves
# 27.007880892177837 Job1-63 is being served
# The number of using resources is 2
# 27.108643222156932 Job1-64 arrives
# 27.490454448193013 Job2-20 arrives
# 27.49074161244185 Job1-62 leaves
# 27.49074161244185 Job1-64 is being served
# The number of using resources is 2
# 27.549852027931625 Job1-64 leaves
# The number of using resources is 2
# 27.549852027931625 Job2-20 is being served
# 27.6823285547511 Job2-20 leaves
# 27.69643480956302 Job1-63 leaves
# 28.385349331121066 Job1-65 arrives
# 28.385349331121066 Job1-65 is being served
# The number of using resources is 1
# 28.399255981324426 Job1-65 leaves
# 28.628032161255643 Job1-66 arrives
# 28.628032161255643 Job1-66 is being served
# The number of using resources is 1
# 28.653638875131822 Job1-67 arrives
# 28.653638875131822 Job1-67 is being served
# The number of using resources is 2
# 28.73060675019214 Job1-67 leaves
# 28.772856900048804 Job1-66 leaves
# 28.801232553380572 Job1-68 arrives
# 28.801232553380572 Job1-68 is being served
# The number of using resources is 1
# 28.98927162695927 Job1-69 arrives
# 28.98927162695927 Job1-69 is being served
# The number of using resources is 2
# 29.021272128251272 Job1-68 leaves
# 29.13002322613015 Job1-69 leaves
# 29.982623086956853 Job1-70 arrives
# 29.982623086956853 Job1-70 is being served
# The number of using resources is 1
# 30.064802396500554 Job1-70 leaves
# 30.08749187018511 Job1-71 arrives
# 30.08749187018511 Job1-71 is being served
# The number of using resources is 1
# 30.26561460979606 Job1-71 leaves
# 30.595997981733742 Job1-72 arrives
# 30.595997981733742 Job1-72 is being served
# The number of using resources is 1
# 30.72073684536655 Job1-72 leaves
# 31.07501341547567 Job1-73 arrives
# 31.07501341547567 Job1-73 is being served
# The number of using resources is 1
# 31.20144281059354 Job1-73 leaves
# 31.582583358336013 Job1-74 arrives
# 31.582583358336013 Job1-74 is being served
# The number of using resources is 1
# 31.652400680204803 Job1-75 arrives
# 31.652400680204803 Job1-75 is being served
# The number of using resources is 2
# 31.966181665413714 Job2-21 arrives
# 31.991307862416143 Job1-75 leaves
# The number of using resources is 2
# 31.991307862416143 Job2-21 is being served
# 32.054677413981246 Job2-21 leaves
# 32.24271209374557 Job1-76 arrives
# 32.24271209374557 Job1-76 is being served
# The number of using resources is 2
# 32.29740151330367 Job1-76 leaves
# 32.34210169617578 Job2-22 arrives
# The number of using resources is 2
# 32.34210169617578 Job2-22 is being served
# 32.55987031355982 Job2-23 arrives
# 32.58469990946685 Job2-24 arrives
# 32.943355479425556 Job1-77 arrives
# 32.943355479425556 Job2-22 got preempted
# 32.943355479425556 Job1-77 is being served
# The number of using resources is 2
# 32.98424004010316 Job1-74 leaves
# The number of using resources is 2
# 32.98424004010316 Job2-23 is being served
# 33.01383930701329 Job1-78 arrives
# 33.01383930701329 Job2-23 got preempted
# 33.01383930701329 Job1-78 is being served
# The number of using resources is 2
# 33.095501723429415 Job2-25 arrives
# 33.18999474344569 Job1-78 leaves
# The number of using resources is 2
# 33.18999474344569 Job2-24 is being served
# 33.278689300570505 Job1-79 arrives
# 33.278689300570505 Job2-24 got preempted
# 33.278689300570505 Job1-79 is being served
# The number of using resources is 2
# 33.45689551150501 Job1-77 leaves
# The number of using resources is 2
# 33.45689551150501 Job2-25 is being served
# 33.48002487171317 Job2-25 leaves
# 33.54515960799608 Job2-26 arrives
# The number of using resources is 2
# 33.54515960799608 Job2-26 is being served
# 33.609068498537134 Job1-79 leaves
# 33.69408932968232 Job2-26 leaves
# 33.70923565497531 Job1-80 arrives
# 33.70923565497531 Job1-80 is being served
# The number of using resources is 1
# 33.745810243090595 Job1-80 leaves
# 33.80637102466289 Job1-81 arrives
# 33.80637102466289 Job1-81 is being served
# The number of using resources is 1
# 33.96870268789849 Job2-27 arrives
# The number of using resources is 2
# 33.96870268789849 Job2-27 is being served
# 34.033366169635755 Job2-28 arrives
# 34.0444368713198 Job1-82 arrives
# 34.0444368713198 Job2-27 got preempted
# 34.0444368713198 Job1-82 is being served
# The number of using resources is 2
# 34.09971006537217 Job1-83 arrives
# 34.19859747963552 Job1-81 leaves
# 34.19859747963552 Job1-83 is being served
# The number of using resources is 2
# 34.2870074227497 Job1-83 leaves
# The number of using resources is 2
# 34.2870074227497 Job2-28 is being served
# 34.39264465773763 Job1-82 leaves
# 34.90175953073951 Job2-28 leaves
# 35.123318169602605 Job2-29 arrives
# The number of using resources is 1
# 35.123318169602605 Job2-29 is being served
# 35.185474445759425 Job2-29 leaves
# 35.37244184622014 Job1-84 arrives
# 35.37244184622014 Job1-84 is being served
# The number of using resources is 1
# 35.51535684838834 Job1-84 leaves
# 35.94705169101888 Job2-30 arrives
# The number of using resources is 1
# 35.94705169101888 Job2-30 is being served
# 36.252282849827786 Job1-85 arrives
# 36.252282849827786 Job1-85 is being served
# The number of using resources is 2
# 36.33814056515674 Job1-86 arrives
# 36.33814056515674 Job2-30 got preempted
# 36.33814056515674 Job1-86 is being served
# The number of using resources is 2
# 36.358439423993104 Job1-86 leaves
# 36.503113102691124 Job1-87 arrives
# 36.503113102691124 Job1-87 is being served
# The number of using resources is 2
# 36.547474351183375 Job2-31 arrives
# 36.636452042969395 Job1-85 leaves
# The number of using resources is 2
# 36.636452042969395 Job2-31 is being served
# 36.654971083805236 Job1-87 leaves
# 36.82577385603419 Job2-31 leaves
# 37.27284778431162 Job1-88 arrives
# 37.27284778431162 Job1-88 is being served
# The number of using resources is 1
# 37.33138657584432 Job2-32 arrives
# The number of using resources is 2
# 37.33138657584432 Job2-32 is being served
# 37.34711504787411 Job2-33 arrives
# 37.36255303964496 Job1-89 arrives
# 37.36255303964496 Job2-32 got preempted
# 37.36255303964496 Job1-89 is being served
# The number of using resources is 2
# 37.481481249964716 Job1-89 leaves
# The number of using resources is 2
# 37.481481249964716 Job2-33 is being served
# 37.511521060651496 Job1-90 arrives
# 37.511521060651496 Job2-33 got preempted
# 37.511521060651496 Job1-90 is being served
# The number of using resources is 2
# 37.705702671334684 Job1-90 leaves
# 38.09481198702978 Job1-91 arrives
# 38.09481198702978 Job1-91 is being served
# The number of using resources is 2
# 38.137268935317266 Job1-88 leaves
# 38.187180522016774 Job1-91 leaves
# 38.52916829523001 Job1-92 arrives
# 38.52916829523001 Job1-92 is being served
# The number of using resources is 1
# 38.54244862179607 Job1-92 leaves
# 38.72964964909026 Job1-93 arrives
# 38.72964964909026 Job1-93 is being served
# The number of using resources is 1
# 38.826005509953795 Job1-94 arrives
# 38.826005509953795 Job1-94 is being served
# The number of using resources is 2
# 38.85188095186296 Job1-94 leaves
# 38.90861444183997 Job1-95 arrives
# 38.90861444183997 Job1-95 is being served
# The number of using resources is 2
# 39.01952625361981 Job1-95 leaves
# 39.30073556105367 Job1-93 leaves
# 39.52139087605103 Job1-96 arrives
# 39.52139087605103 Job1-96 is being served
# The number of using resources is 1
# 39.53543461360773 Job2-34 arrives
# The number of using resources is 2
# 39.53543461360773 Job2-34 is being served
# 39.57659724482579 Job1-97 arrives
# 39.57659724482579 Job2-34 got preempted
# 39.57659724482579 Job1-97 is being served
# The number of using resources is 2
# 39.69397504823207 Job1-98 arrives
# 39.78275698521574 Job2-35 arrives
# 39.81905170004978 Job2-36 arrives
# 40.1949590474676 Job1-96 leaves
# 40.1949590474676 Job1-98 is being served
# The number of using resources is 2
# 40.31848186509099 Job1-97 leaves
# The number of using resources is 2
# 40.31848186509099 Job2-35 is being served
# 40.61718300875633 Job1-99 arrives
# 40.61718300875633 Job2-35 got preempted
# 40.61718300875633 Job1-99 is being served
# The number of using resources is 2
# 40.824504500258435 Job1-100 arrives
# 40.827093342000026 Job2-37 arrives
# 40.84203468158878 Job1-99 leaves
# 40.84203468158878 Job1-100 is being served
# The number of using resources is 2
# 40.91519603361874 Job1-101 arrives
# 41.02150013631752 Job1-98 leaves
# 41.02150013631752 Job1-101 is being served
# The number of using resources is 2
# 41.03610336394869 Job2-38 arrives
# 41.18180432214114 Job1-101 leaves
# The number of using resources is 2
# 41.18180432214114 Job2-36 is being served
# 41.275669532061855 Job2-36 leaves
# The number of using resources is 2
# 41.275669532061855 Job2-37 is being served
# 41.42579540953866 Job1-100 leaves
# The number of using resources is 2
# 41.42579540953866 Job2-38 is being served
# 41.47760922928484 Job2-37 leaves
# 41.57366577704828 Job1-102 arrives
# 41.57366577704828 Job1-102 is being served
# The number of using resources is 2
# 41.99457419403475 Job1-103 arrives
# 41.99457419403475 Job2-38 got preempted
# 41.99457419403475 Job1-103 is being served
# The number of using resources is 2
# 42.091716625090456 Job1-102 leaves
# 42.14765135059843 Job1-103 leaves
# 43.26171531474103 Job2-39 arrives
# The number of using resources is 1
# 43.26171531474103 Job2-39 is being served
# 43.739089808474226 Job2-39 leaves
# 44.8021383596719 Job2-40 arrives
# The number of using resources is 1
# 44.8021383596719 Job2-40 is being served
# 44.84398467277133 Job2-41 arrives
# The number of using resources is 2
# 44.84398467277133 Job2-41 is being served
# 44.972741273902024 Job2-42 arrives
# 45.032794393381224 Job2-41 leaves
# The number of using resources is 2
# 45.032794393381224 Job2-42 is being served
# 45.06119578800672 Job2-40 leaves
# 45.223605718081515 Job1-104 arrives
# 45.223605718081515 Job1-104 is being served
# The number of using resources is 2
# 45.264997811965934 Job1-104 leaves
# 45.3414128163191 Job2-42 leaves
# 45.66198496239896 Job2-43 arrives
# The number of using resources is 1
# 45.66198496239896 Job2-43 is being served
# 45.70573303199408 Job2-44 arrives
# The number of using resources is 2
# 45.70573303199408 Job2-44 is being served
# 45.781334628921975 Job2-44 leaves
# 45.88476713067442 Job1-105 arrives
# 45.88476713067442 Job1-105 is being served
# The number of using resources is 2
# 45.97977177319809 Job1-105 leaves
# 46.26301309339421 Job2-43 leaves
# 46.59663248649463 Job2-45 arrives
# The number of using resources is 1
# 46.59663248649463 Job2-45 is being served
# 47.22697223577885 Job2-45 leaves
# 47.94127273635888 Job1-106 arrives
# 47.94127273635888 Job1-106 is being served
# The number of using resources is 1
# 47.954208715916245 Job1-107 arrives
# 47.954208715916245 Job1-107 is being served
# The number of using resources is 2
# 48.049911931577846 Job1-107 leaves
# 48.072830435853895 Job1-106 leaves
# 48.360222350040004 Job2-46 arrives
# The number of using resources is 1
# 48.360222350040004 Job2-46 is being served
# 48.427405833977744 Job2-46 leaves
# 48.58839233494024 Job2-47 arrives
# The number of using resources is 1
# 48.58839233494024 Job2-47 is being served
# 49.017610526473234 Job2-47 leaves
# 49.694611418733125 Job2-48 arrives
# The number of using resources is 1
# 49.694611418733125 Job2-48 is being served
# 49.70763448039214 Job2-48 leaves
# 49.72205585985978 Job2-49 arrives
# The number of using resources is 1
# 49.72205585985978 Job2-49 is being served
# 49.7646287674779 Job2-49 leaves

# %% [markdown]
# <a href="https://colab.research.google.com/github/qriovider/queueing_theory/blob/main/priority_2type_jobs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.7/dist-packages (4.0.1)

# %%
import simpy
import numpy as np
import matplotlib.pyplot as plt

# %%
LAMBDA_1 = 2
LAMBDA_2 = 1
MU_1 = 4
MU_2 = 3

def generate_interarrival(LAMBDA):
  return np.random.exponential(1./LAMBDA)

def generate_service(MU):
  return np.random.exponential(1./MU)

def arriving_1(env, resource):
  i = 0
  while True:
    i = i + 1
    job1 = Job1(name="Job1-{}".format(i))
    yield env.timeout(generate_interarrival(LAMBDA_1))
    print(env.now, job1.name, 'arrives')
    env.process(job1.resource_user_1(env, i, resource))

def arriving_2(env, resource):
  i = 0
  while True:
    i = i + 1
    job2 = Job2(name="Job2-{}".format(i))
    yield env.timeout(generate_interarrival(LAMBDA_2))
    print(env.now, job2.name, 'arrives')
    env.process(job2.resource_user_2(env, i, resource))

class Job1(object):
  def __init__(self, name):
    self.name = name

  def resource_user_1(self, env, i, resource):
    print(self.name, 'is waiting')
    with resource.request(priority=1) as req:
      yield req
      print(env.now, self.name, 'is being served')
      print('The number of using resources is', resource.count)
      yield env.timeout(generate_service(MU_1))
      print(env.now, self.name, 'finishes')

class Job2(object):
  def __init__(self, name):
    self.name = name

  def resource_user_2(self, env, i, resource):
    print(self.name, 'is waiting')
    with resource.request(priority=2) as req:
      yield req
      print(env.now, self.name, 'is being served')
      print('The number of using resources is', resource.count)
      yield env.timeout(generate_service(MU_2))
      print(env.now, self.name, 'finishes')

# %%
env = simpy.Environment()
resource = simpy.PriorityResource(env, capacity=2)
env.process(arriving_1(env, resource))
env.process(arriving_2(env, resource))
env.run(until=50)
# Out:
# 0.9297215994220479 Job1-1 arrives
# Job1-1 is waiting
# 0.9297215994220479 Job1-1 is being served
# The number of using resources is 1
# 0.945221021125872 Job1-1 finishes
# 0.9726974313053189 Job2-1 arrives
# Job2-1 is waiting
# 0.9726974313053189 Job2-1 is being served
# The number of using resources is 1
# 1.0587305964536957 Job1-2 arrives
# Job1-2 is waiting
# 1.0587305964536957 Job1-2 is being served
# The number of using resources is 2
# 1.061763117391646 Job1-2 finishes
# 1.2359655509005059 Job1-3 arrives
# Job1-3 is waiting
# 1.2359655509005059 Job1-3 is being served
# The number of using resources is 2
# 1.554562654564449 Job1-4 arrives
# Job1-4 is waiting
# 1.5756712348164228 Job2-2 arrives
# Job2-2 is waiting
# 1.6384178667263818 Job2-1 finishes
# 1.6384178667263818 Job1-4 is being served
# The number of using resources is 2
# 1.639049797463754 Job1-3 finishes
# 1.639049797463754 Job2-2 is being served
# The number of using resources is 2
# 1.7939633373771826 Job2-2 finishes
# 1.806949194700167 Job1-5 arrives
# Job1-5 is waiting
# 1.806949194700167 Job1-5 is being served
# The number of using resources is 2
# 1.9560144302319542 Job2-3 arrives
# Job2-3 is waiting
# 2.046831852339446 Job1-6 arrives
# Job1-6 is waiting
# 2.1083022823905377 Job1-5 finishes
# 2.1083022823905377 Job1-6 is being served
# The number of using resources is 2
# 2.62741160106681 Job1-4 finishes
# 2.62741160106681 Job2-3 is being served
# The number of using resources is 2
# 2.7594961492957255 Job1-6 finishes
# 2.997634909200605 Job2-3 finishes
# 4.062108786398802 Job1-7 arrives
# Job1-7 is waiting
# 4.062108786398802 Job1-7 is being served
# The number of using resources is 1
# 4.1510758212304575 Job1-7 finishes
# 4.624030320188225 Job1-8 arrives
# Job1-8 is waiting
# 4.624030320188225 Job1-8 is being served
# The number of using resources is 1
# 4.67378234037813 Job1-8 finishes
# 4.98527397508157 Job1-9 arrives
# Job1-9 is waiting
# 4.98527397508157 Job1-9 is being served
# The number of using resources is 1
# 5.513052330196208 Job1-9 finishes
# 5.746424167904243 Job1-10 arrives
# Job1-10 is waiting
# 5.746424167904243 Job1-10 is being served
# The number of using resources is 1
# 6.105868244222388 Job1-10 finishes
# 6.173524451116438 Job1-11 arrives
# Job1-11 is waiting
# 6.173524451116438 Job1-11 is being served
# The number of using resources is 1
# 6.2535917529629375 Job1-11 finishes
# 6.33329771070088 Job1-12 arrives
# Job1-12 is waiting
# 6.33329771070088 Job1-12 is being served
# The number of using resources is 1
# 6.3339804014464445 Job1-13 arrives
# Job1-13 is waiting
# 6.3339804014464445 Job1-13 is being served
# The number of using resources is 2
# 6.434600730469862 Job1-13 finishes
# 6.691333182354763 Job1-12 finishes
# 6.691633582696764 Job1-14 arrives
# Job1-14 is waiting
# 6.691633582696764 Job1-14 is being served
# The number of using resources is 1
# 6.838132278136003 Job1-14 finishes
# 6.911361824412686 Job1-15 arrives
# Job1-15 is waiting
# 6.911361824412686 Job1-15 is being served
# The number of using resources is 1
# 7.049132504240671 Job2-4 arrives
# Job2-4 is waiting
# 7.049132504240671 Job2-4 is being served
# The number of using resources is 2
# 7.0680951945919315 Job1-15 finishes
# 7.182634495468674 Job2-4 finishes
# 7.209769451042505 Job1-16 arrives
# Job1-16 is waiting
# 7.209769451042505 Job1-16 is being served
# The number of using resources is 1
# 7.557587630440453 Job2-5 arrives
# Job2-5 is waiting
# 7.557587630440453 Job2-5 is being served
# The number of using resources is 2
# 7.627080064659576 Job1-16 finishes
# 7.807727511646682 Job1-17 arrives
# Job1-17 is waiting
# 7.807727511646682 Job1-17 is being served
# The number of using resources is 2
# 7.811660219041372 Job2-5 finishes
# 8.183721637199232 Job1-17 finishes
# 9.211370668522228 Job1-18 arrives
# Job1-18 is waiting
# 9.211370668522228 Job1-18 is being served
# The number of using resources is 1
# 9.213607340036466 Job1-18 finishes
# 9.346244760257498 Job2-6 arrives
# Job2-6 is waiting
# 9.346244760257498 Job2-6 is being served
# The number of using resources is 1
# 9.430890514338948 Job2-6 finishes
# 10.121448603736894 Job2-7 arrives
# Job2-7 is waiting
# 10.121448603736894 Job2-7 is being served
# The number of using resources is 1
# 10.17074882755615 Job1-19 arrives
# Job1-19 is waiting
# 10.17074882755615 Job1-19 is being served
# The number of using resources is 2
# 10.19810791409878 Job1-19 finishes
# 10.305576398667965 Job2-7 finishes
# 10.55317729804758 Job1-20 arrives
# Job1-20 is waiting
# 10.55317729804758 Job1-20 is being served
# The number of using resources is 1
# 10.689391708305754 Job1-20 finishes
# 10.904664778211783 Job1-21 arrives
# Job1-21 is waiting
# 10.904664778211783 Job1-21 is being served
# The number of using resources is 1
# 11.10323936370932 Job2-8 arrives
# Job2-8 is waiting
# 11.10323936370932 Job2-8 is being served
# The number of using resources is 2
# 11.114579863127638 Job1-21 finishes
# 11.227093384871477 Job1-22 arrives
# Job1-22 is waiting
# 11.227093384871477 Job1-22 is being served
# The number of using resources is 2
# 11.500122343004819 Job1-23 arrives
# Job1-23 is waiting
# 11.5644565195011 Job2-8 finishes
# 11.5644565195011 Job1-23 is being served
# The number of using resources is 2
# 11.679347240444054 Job1-22 finishes
# 11.927837850560305 Job1-24 arrives
# Job1-24 is waiting
# 11.927837850560305 Job1-24 is being served
# The number of using resources is 2
# 11.93833128827978 Job1-23 finishes
# 12.227830470187305 Job1-24 finishes
# 13.109651010620208 Job1-25 arrives
# Job1-25 is waiting
# 13.109651010620208 Job1-25 is being served
# The number of using resources is 1
# 13.140153054630721 Job2-9 arrives
# Job2-9 is waiting
# 13.140153054630721 Job2-9 is being served
# The number of using resources is 2
# 13.228660682147897 Job1-25 finishes
# 13.237112590939347 Job2-9 finishes
# 14.788599036995455 Job2-10 arrives
# Job2-10 is waiting
# 14.788599036995455 Job2-10 is being served
# The number of using resources is 1
# 15.057836371435977 Job1-26 arrives
# Job1-26 is waiting
# 15.057836371435977 Job1-26 is being served
# The number of using resources is 2
# 15.169826473550781 Job1-26 finishes
# 15.344973083728782 Job1-27 arrives
# Job1-27 is waiting
# 15.344973083728782 Job1-27 is being served
# The number of using resources is 2
# 15.543698747899597 Job1-28 arrives
# Job1-28 is waiting
# 15.79793444417213 Job1-27 finishes
# 15.79793444417213 Job1-28 is being served
# The number of using resources is 2
# 15.872322554597607 Job2-11 arrives
# Job2-11 is waiting
# 15.982372294258164 Job2-12 arrives
# Job2-12 is waiting
# 16.008321164247455 Job1-29 arrives
# Job1-29 is waiting
# 16.15243593722927 Job1-28 finishes
# 16.15243593722927 Job1-29 is being served
# The number of using resources is 2
# 16.26001022751588 Job2-10 finishes
# 16.26001022751588 Job2-11 is being served
# The number of using resources is 2
# 16.4738323680427 Job2-11 finishes
# 16.4738323680427 Job2-12 is being served
# The number of using resources is 2
# 16.567545810597387 Job1-30 arrives
# Job1-30 is waiting
# 16.620861649684556 Job1-29 finishes
# 16.620861649684556 Job1-30 is being served
# The number of using resources is 2
# 16.67131390189009 Job1-30 finishes
# 16.906867115636967 Job2-13 arrives
# Job2-13 is waiting
# 16.906867115636967 Job2-13 is being served
# The number of using resources is 2
# 16.96998851149365 Job2-13 finishes
# 17.123552405475948 Job2-14 arrives
# Job2-14 is waiting
# 17.123552405475948 Job2-14 is being served
# The number of using resources is 2
# 17.224343325213407 Job2-14 finishes
# 17.656572976593864 Job2-12 finishes
# 17.93482867789648 Job1-31 arrives
# Job1-31 is waiting
# 17.93482867789648 Job1-31 is being served
# The number of using resources is 1
# 18.018766150557724 Job1-31 finishes
# 18.347832106134028 Job1-32 arrives
# Job1-32 is waiting
# 18.347832106134028 Job1-32 is being served
# The number of using resources is 1
# 18.360231711760942 Job1-32 finishes
# 19.736498715559925 Job1-33 arrives
# Job1-33 is waiting
# 19.736498715559925 Job1-33 is being served
# The number of using resources is 1
# 19.753205243166253 Job2-15 arrives
# Job2-15 is waiting
# 19.753205243166253 Job2-15 is being served
# The number of using resources is 2
# 19.77078524280882 Job1-33 finishes
# 19.778002418835108 Job2-15 finishes
# 19.84666506426855 Job1-34 arrives
# Job1-34 is waiting
# 19.84666506426855 Job1-34 is being served
# The number of using resources is 1
# 19.917379865979232 Job1-35 arrives
# Job1-35 is waiting
# 19.917379865979232 Job1-35 is being served
# The number of using resources is 2
# 19.981552668185262 Job1-34 finishes
# 19.984475803999608 Job1-36 arrives
# Job1-36 is waiting
# 19.984475803999608 Job1-36 is being served
# The number of using resources is 2
# 20.353379492326354 Job2-16 arrives
# Job2-16 is waiting
# 20.525880750499425 Job1-35 finishes
# 20.525880750499425 Job2-16 is being served
# The number of using resources is 2
# 20.568255302320622 Job1-37 arrives
# Job1-37 is waiting
# 20.57580304319156 Job1-38 arrives
# Job1-38 is waiting
# 20.812320537707453 Job1-36 finishes
# 20.812320537707453 Job1-37 is being served
# The number of using resources is 2
# 21.04733930427773 Job1-37 finishes
# 21.04733930427773 Job1-38 is being served
# The number of using resources is 2
# 21.054565163205897 Job1-38 finishes
# 21.55256488080551 Job2-16 finishes
# 21.690791597812005 Job2-17 arrives
# Job2-17 is waiting
# 21.690791597812005 Job2-17 is being served
# The number of using resources is 1
# 21.72643859811861 Job1-39 arrives
# Job1-39 is waiting
# 21.72643859811861 Job1-39 is being served
# The number of using resources is 2
# 21.764575724795073 Job1-39 finishes
# 21.855917245279617 Job2-17 finishes
# 22.592381240093193 Job1-40 arrives
# Job1-40 is waiting
# 22.592381240093193 Job1-40 is being served
# The number of using resources is 1
# 22.672990044253734 Job1-41 arrives
# Job1-41 is waiting
# 22.672990044253734 Job1-41 is being served
# The number of using resources is 2
# 22.775564447235578 Job1-42 arrives
# Job1-42 is waiting
# 22.877836028419974 Job1-41 finishes
# 22.877836028419974 Job1-42 is being served
# The number of using resources is 2
# 23.00021545856053 Job1-43 arrives
# Job1-43 is waiting
# 23.02242918476332 Job1-40 finishes
# 23.02242918476332 Job1-43 is being served
# The number of using resources is 2
# 23.159365573445548 Job1-44 arrives
# Job1-44 is waiting
# 23.21835691447071 Job1-43 finishes
# 23.21835691447071 Job1-44 is being served
# The number of using resources is 2
# 23.29897933267733 Job2-18 arrives
# Job2-18 is waiting
# 23.339806368773772 Job1-42 finishes
# 23.339806368773772 Job2-18 is being served
# The number of using resources is 2
# 23.388987946486875 Job1-44 finishes
# 23.53476960736742 Job2-18 finishes
# 24.893875477507688 Job2-19 arrives
# Job2-19 is waiting
# 24.893875477507688 Job2-19 is being served
# The number of using resources is 1
# 24.98841075100999 Job1-45 arrives
# Job1-45 is waiting
# 24.98841075100999 Job1-45 is being served
# The number of using resources is 2
# 25.12842363696236 Job2-19 finishes
# 25.34247633645218 Job1-45 finishes
# 25.442704350819426 Job1-46 arrives
# Job1-46 is waiting
# 25.442704350819426 Job1-46 is being served
# The number of using resources is 1
# 25.582510089788165 Job1-46 finishes
# 25.966655457068246 Job1-47 arrives
# Job1-47 is waiting
# 25.966655457068246 Job1-47 is being served
# The number of using resources is 1
# 26.050631236593112 Job1-48 arrives
# Job1-48 is waiting
# 26.050631236593112 Job1-48 is being served
# The number of using resources is 2
# 26.17898808220452 Job1-48 finishes
# 26.206765598490062 Job2-20 arrives
# Job2-20 is waiting
# 26.206765598490062 Job2-20 is being served
# The number of using resources is 2
# 26.293152484589093 Job2-20 finishes
# 26.360774608795122 Job1-47 finishes
# 26.4265134062529 Job2-21 arrives
# Job2-21 is waiting
# 26.4265134062529 Job2-21 is being served
# The number of using resources is 1
# 26.491121053025424 Job2-21 finishes
# 26.71473253085809 Job1-49 arrives
# Job1-49 is waiting
# 26.71473253085809 Job1-49 is being served
# The number of using resources is 1
# 26.823538859307273 Job1-50 arrives
# Job1-50 is waiting
# 26.823538859307273 Job1-50 is being served
# The number of using resources is 2
# 26.905948861246905 Job1-51 arrives
# Job1-51 is waiting
# 26.92936915611572 Job1-50 finishes
# 26.92936915611572 Job1-51 is being served
# The number of using resources is 2
# 27.05559333682994 Job1-52 arrives
# Job1-52 is waiting
# 27.28755585345483 Job1-49 finishes
# 27.28755585345483 Job1-52 is being served
# The number of using resources is 2
# 27.300825248849325 Job1-52 finishes
# 27.310463360111537 Job1-53 arrives
# Job1-53 is waiting
# 27.310463360111537 Job1-53 is being served
# The number of using resources is 2
# 27.40438788168088 Job1-54 arrives
# Job1-54 is waiting
# 27.407375784543767 Job1-51 finishes
# 27.407375784543767 Job1-54 is being served
# The number of using resources is 2
# 27.481466461934406 Job1-53 finishes
# 27.810783822191407 Job1-55 arrives
# Job1-55 is waiting
# 27.810783822191407 Job1-55 is being served
# The number of using resources is 2
# 27.928080047680695 Job2-22 arrives
# Job2-22 is waiting
# 27.945592824525768 Job1-56 arrives
# Job1-56 is waiting
# 28.040266357761183 Job1-55 finishes
# 28.040266357761183 Job1-56 is being served
# The number of using resources is 2
# 28.3815740711343 Job1-56 finishes
# 28.3815740711343 Job2-22 is being served
# The number of using resources is 2
# 28.396811054484985 Job1-54 finishes
# 28.473227042406386 Job2-22 finishes
# 28.626119419451538 Job1-57 arrives
# Job1-57 is waiting
# 28.626119419451538 Job1-57 is being served
# The number of using resources is 1
# 28.875059093347705 Job1-57 finishes
# 28.992694835455463 Job1-58 arrives
# Job1-58 is waiting
# 28.992694835455463 Job1-58 is being served
# The number of using resources is 1
# 29.137744215800765 Job1-59 arrives
# Job1-59 is waiting
# 29.137744215800765 Job1-59 is being served
# The number of using resources is 2
# 29.39250308641266 Job1-59 finishes
# 29.657337105021625 Job1-58 finishes
# 30.404120902044212 Job1-60 arrives
# Job1-60 is waiting
# 30.404120902044212 Job1-60 is being served
# The number of using resources is 1
# 30.417145688516296 Job1-60 finishes
# 31.638047346175497 Job2-23 arrives
# Job2-23 is waiting
# 31.638047346175497 Job2-23 is being served
# The number of using resources is 1
# 31.897272366407027 Job1-61 arrives
# Job1-61 is waiting
# 31.897272366407027 Job1-61 is being served
# The number of using resources is 2
# 31.90425506674049 Job2-23 finishes
# 31.943391305248486 Job1-61 finishes
# 32.071998359045324 Job1-62 arrives
# Job1-62 is waiting
# 32.071998359045324 Job1-62 is being served
# The number of using resources is 1
# 32.075092214212 Job1-62 finishes
# 32.66956788362289 Job1-63 arrives
# Job1-63 is waiting
# 32.66956788362289 Job1-63 is being served
# The number of using resources is 1
# 32.67659351579366 Job1-63 finishes
# 32.683400963392515 Job2-24 arrives
# Job2-24 is waiting
# 32.683400963392515 Job2-24 is being served
# The number of using resources is 1
# 32.70079903987842 Job1-64 arrives
# Job1-64 is waiting
# 32.70079903987842 Job1-64 is being served
# The number of using resources is 2
# 32.76905307404145 Job2-24 finishes
# 32.901375090463596 Job1-65 arrives
# Job1-65 is waiting
# 32.901375090463596 Job1-65 is being served
# The number of using resources is 2
# 32.92070181461805 Job2-25 arrives
# Job2-25 is waiting
# 32.95642001945793 Job1-64 finishes
# 32.95642001945793 Job2-25 is being served
# The number of using resources is 2
# 32.96220488333996 Job1-66 arrives
# Job1-66 is waiting
# 32.96288406602195 Job1-65 finishes
# 32.96288406602195 Job1-66 is being served
# The number of using resources is 2
# 33.12532612903451 Job1-67 arrives
# Job1-67 is waiting
# 33.12584066181142 Job2-25 finishes
# 33.12584066181142 Job1-67 is being served
# The number of using resources is 2
# 33.25479753823864 Job1-67 finishes
# 33.323521804334845 Job1-66 finishes
# 33.76839652148433 Job1-68 arrives
# Job1-68 is waiting
# 33.76839652148433 Job1-68 is being served
# The number of using resources is 1
# 33.82609685822282 Job1-69 arrives
# Job1-69 is waiting
# 33.82609685822282 Job1-69 is being served
# The number of using resources is 2
# 33.92942929047517 Job1-68 finishes
# 33.97400983567381 Job2-26 arrives
# Job2-26 is waiting
# 33.97400983567381 Job2-26 is being served
# The number of using resources is 2
# 34.04391207572451 Job1-69 finishes
# 34.27021072132253 Job2-26 finishes
# 34.63276299330412 Job2-27 arrives
# Job2-27 is waiting
# 34.63276299330412 Job2-27 is being served
# The number of using resources is 1
# 34.842594516188925 Job1-70 arrives
# Job1-70 is waiting
# 34.842594516188925 Job1-70 is being served
# The number of using resources is 2
# 34.92530626556593 Job1-70 finishes
# 35.172852884600964 Job1-71 arrives
# Job1-71 is waiting
# 35.172852884600964 Job1-71 is being served
# The number of using resources is 2
# 35.358905830622525 Job1-71 finishes
# 35.3644370708249 Job2-27 finishes
# 36.22583875719769 Job1-72 arrives
# Job1-72 is waiting
# 36.22583875719769 Job1-72 is being served
# The number of using resources is 1
# 36.27182326255287 Job1-73 arrives
# Job1-73 is waiting
# 36.27182326255287 Job1-73 is being served
# The number of using resources is 2
# 36.29803918658579 Job1-73 finishes
# 36.32794122287738 Job1-72 finishes
# 36.808929744514536 Job1-74 arrives
# Job1-74 is waiting
# 36.808929744514536 Job1-74 is being served
# The number of using resources is 1
# 37.13146864946117 Job1-74 finishes
# 37.62427465486769 Job1-75 arrives
# Job1-75 is waiting
# 37.62427465486769 Job1-75 is being served
# The number of using resources is 1
# 37.7810863823842 Job1-75 finishes
# 38.27692663389992 Job1-76 arrives
# Job1-76 is waiting
# 38.27692663389992 Job1-76 is being served
# The number of using resources is 1
# 38.50724065574592 Job2-28 arrives
# Job2-28 is waiting
# 38.50724065574592 Job2-28 is being served
# The number of using resources is 2
# 38.59111710191075 Job1-77 arrives
# Job1-77 is waiting
# 38.6172758617835 Job2-28 finishes
# 38.6172758617835 Job1-77 is being served
# The number of using resources is 2
# 38.84407731415341 Job1-77 finishes
# 38.907884693879176 Job1-76 finishes
# 39.624945776674636 Job1-78 arrives
# Job1-78 is waiting
# 39.624945776674636 Job1-78 is being served
# The number of using resources is 1
# 39.68945569006702 Job1-78 finishes
# 40.052473659553165 Job2-29 arrives
# Job2-29 is waiting
# 40.052473659553165 Job2-29 is being served
# The number of using resources is 1
# 40.23833164430335 Job1-79 arrives
# Job1-79 is waiting
# 40.23833164430335 Job1-79 is being served
# The number of using resources is 2
# 40.29118414314474 Job2-30 arrives
# Job2-30 is waiting
# 40.35586441216111 Job1-80 arrives
# Job1-80 is waiting
# 40.62943311152324 Job1-81 arrives
# Job1-81 is waiting
# 40.67900744816327 Job1-82 arrives
# Job1-82 is waiting
# 40.81112816930744 Job2-29 finishes
# 40.81112816930744 Job1-80 is being served
# The number of using resources is 2
# 41.00781514240002 Job1-80 finishes
# 41.00781514240002 Job1-81 is being served
# The number of using resources is 2
# 41.18773844574097 Job1-79 finishes
# 41.18773844574097 Job1-82 is being served
# The number of using resources is 2
# 41.190246535521915 Job1-81 finishes
# 41.190246535521915 Job2-30 is being served
# The number of using resources is 2
# 41.218495505561734 Job1-82 finishes
# 41.222475603437275 Job2-30 finishes
# 41.50890034028271 Job2-31 arrives
# Job2-31 is waiting
# 41.50890034028271 Job2-31 is being served
# The number of using resources is 1
# 41.6606037754098 Job2-32 arrives
# Job2-32 is waiting
# 41.6606037754098 Job2-32 is being served
# The number of using resources is 2
# 41.75635430903318 Job2-31 finishes
# 41.80524240758227 Job1-83 arrives
# Job1-83 is waiting
# 41.80524240758227 Job1-83 is being served
# The number of using resources is 2
# 41.87540679534905 Job1-83 finishes
# 42.228356178481995 Job2-32 finishes
# 42.68543510204614 Job1-84 arrives
# Job1-84 is waiting
# 42.68543510204614 Job1-84 is being served
# The number of using resources is 1
# 43.250356820990895 Job1-85 arrives
# Job1-85 is waiting
# 43.250356820990895 Job1-85 is being served
# The number of using resources is 2
# 43.274109509121516 Job1-86 arrives
# Job1-86 is waiting
# 43.360884915348464 Job1-85 finishes
# 43.360884915348464 Job1-86 is being served
# The number of using resources is 2
# 43.37685328579442 Job1-87 arrives
# Job1-87 is waiting
# 43.42464917700994 Job2-33 arrives
# Job2-33 is waiting
# 43.568913723509205 Job1-88 arrives
# Job1-88 is waiting
# 43.57232232487412 Job1-84 finishes
# 43.57232232487412 Job1-87 is being served
# The number of using resources is 2
# 43.59599757373378 Job1-86 finishes
# 43.59599757373378 Job1-88 is being served
# The number of using resources is 2
# 43.61071842148209 Job1-87 finishes
# 43.61071842148209 Job2-33 is being served
# The number of using resources is 2
# 43.8978172154489 Job1-88 finishes
# 43.970657044070904 Job2-33 finishes
# 44.1208596322153 Job1-89 arrives
# Job1-89 is waiting
# 44.1208596322153 Job1-89 is being served
# The number of using resources is 1
# 44.15775719348733 Job2-34 arrives
# Job2-34 is waiting
# 44.15775719348733 Job2-34 is being served
# The number of using resources is 2
# 44.15904570113516 Job1-89 finishes
# 44.38515593474989 Job1-90 arrives
# Job1-90 is waiting
# 44.38515593474989 Job1-90 is being served
# The number of using resources is 2
# 44.41639731438419 Job1-91 arrives
# Job1-91 is waiting
# 44.50859586417089 Job1-90 finishes
# 44.50859586417089 Job1-91 is being served
# The number of using resources is 2
# 44.59042776261258 Job1-92 arrives
# Job1-92 is waiting
# 44.64619212572657 Job2-34 finishes
# 44.64619212572657 Job1-92 is being served
# The number of using resources is 2
# 44.675498662798816 Job1-91 finishes
# 44.80243148826012 Job1-93 arrives
# Job1-93 is waiting
# 44.80243148826012 Job1-93 is being served
# The number of using resources is 2
# 44.86798797423437 Job1-92 finishes
# 44.880716443954704 Job1-93 finishes
# 44.904185281161446 Job1-94 arrives
# Job1-94 is waiting
# 44.904185281161446 Job1-94 is being served
# The number of using resources is 1
# 44.97210677316528 Job1-94 finishes
# 45.486216485837126 Job1-95 arrives
# Job1-95 is waiting
# 45.486216485837126 Job1-95 is being served
# The number of using resources is 1
# 45.49368939288468 Job1-95 finishes
# 45.75675075922414 Job1-96 arrives
# Job1-96 is waiting
# 45.75675075922414 Job1-96 is being served
# The number of using resources is 1
# 45.803094231922756 Job1-97 arrives
# Job1-97 is waiting
# 45.803094231922756 Job1-97 is being served
# The number of using resources is 2
# 45.825854601968935 Job1-96 finishes
# 45.89539820765188 Job1-97 finishes
# 45.92192714980805 Job2-35 arrives
# Job2-35 is waiting
# 45.92192714980805 Job2-35 is being served
# The number of using resources is 1
# 46.04380854302655 Job1-98 arrives
# Job1-98 is waiting
# 46.04380854302655 Job1-98 is being served
# The number of using resources is 2
# 46.17845197895064 Job2-36 arrives
# Job2-36 is waiting
# 46.43527739192945 Job1-98 finishes
# 46.43527739192945 Job2-36 is being served
# The number of using resources is 2
# 46.44328758649944 Job1-99 arrives
# Job1-99 is waiting
# 46.475829046511755 Job1-100 arrives
# Job1-100 is waiting
# 46.55039505110505 Job2-37 arrives
# Job2-37 is waiting
# 46.569143146474545 Job2-35 finishes
# 46.569143146474545 Job1-99 is being served
# The number of using resources is 2
# 46.71277476258815 Job2-36 finishes
# 46.71277476258815 Job1-100 is being served
# The number of using resources is 2
# 46.75343151481018 Job1-100 finishes
# 46.75343151481018 Job2-37 is being served
# The number of using resources is 2
# 46.91723032048968 Job2-37 finishes
# 46.94517042019783 Job1-101 arrives
# Job1-101 is waiting
# 46.94517042019783 Job1-101 is being served
# The number of using resources is 2
# 46.99182437635969 Job1-101 finishes
# 47.06118631459782 Job1-99 finishes
# 47.52330256255996 Job1-102 arrives
# Job1-102 is waiting
# 47.52330256255996 Job1-102 is being served
# The number of using resources is 1
# 47.63545496770119 Job1-102 finishes

# %% [markdown]
# <a href="https://colab.research.google.com/github/qriovider/queueing_theory/blob/main/priority_2type_jobs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.0.1-py2.py3-none-any.whl (29 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.0.1

# %%
import simpy
import numpy as np
import matplotlib.pyplot as plt

# %%
LAMBDA_1 = 2
LAMBDA_2 = 1
MU_1 = 4
MU_2 = 3

def generate_interarrival(LAMBDA):
  return np.random.exponential(1./LAMBDA)

def generate_service(MU):
  return np.random.exponential(1./MU)

class Job1(object):
  def __init__(self, name):
    self.name = name

class Job2(object):
  def __init__(self, name):
    self.name = name

def arriving_1(env, resource):
  i = 0
  while True:
    i = i + 1
    job1 = Job1(name="Job1-{}".format(i))
    yield env.timeout(generate_interarrival(LAMBDA_1))
    print(env.now, job1.name, 'arrives')
    env.process(resource_user_1(env, i, resource))

def arriving_2(env, resource):
  i = 0
  while True:
    i = i + 1
    job2 = Job2(name="Job2-{}".format(i))
    yield env.timeout(generate_interarrival(LAMBDA_2))
    print(env.now, job2.name, 'arrives')
    env.process(resource_user_2(env, i, resource))

def resource_user_1(env, i, resource):
  job1 = Job1(name="Job1-{}".format(i))
  print(job1.name, 'is waiting')
  with resource.request(priority=1) as req:
    yield req
    print(env.now, job1.name, 'is being served')
    print('The number of using resources is', resource.count)
    yield env.timeout(generate_service(MU_1))
    print(env.now, job1.name, 'finishes')

def resource_user_2(env, i, resource):
  job2 = Job2(name="Job2-{}".format(i))
  print(job2.name, 'is waiting')
  with resource.request(priority=2) as req:
    yield req
    print(env.now, job2.name, 'is being served')
    print('The number of using resources is', resource.count)
    yield env.timeout(generate_service(MU_2))
    print(env.now, job2.name, 'finishes')

# %%
env = simpy.Environment()
resource = simpy.PriorityResource(env, capacity=2)
env.process(arriving_1(env, resource))
env.process(arriving_2(env, resource))
env.run(until=50)
# Out:
# 0.08586413475352359 Job1-1 arrives
# Job1-1 is waiting
# 0.08586413475352359 Job1-1 is being served
# The number of using resources is 1
# 0.09327981502345034 Job1-1 finishes
# 0.40946187766046593 Job2-1 arrives
# Job2-1 is waiting
# 0.40946187766046593 Job2-1 is being served
# The number of using resources is 1
# 0.6163345424712517 Job2-1 finishes
# 0.9452455439063079 Job1-2 arrives
# Job1-2 is waiting
# 0.9452455439063079 Job1-2 is being served
# The number of using resources is 1
# 1.0272176431179023 Job1-2 finishes
# 1.3127517419467973 Job1-3 arrives
# Job1-3 is waiting
# 1.3127517419467973 Job1-3 is being served
# The number of using resources is 1
# 1.4009511293032324 Job1-4 arrives
# Job1-4 is waiting
# 1.4009511293032324 Job1-4 is being served
# The number of using resources is 2
# 1.7395101510259394 Job1-4 finishes
# 1.8344925043250495 Job1-3 finishes
# 2.9258492207577524 Job2-2 arrives
# Job2-2 is waiting
# 2.9258492207577524 Job2-2 is being served
# The number of using resources is 1
# 3.285490196422783 Job2-2 finishes
# 3.382402476477939 Job2-3 arrives
# Job2-3 is waiting
# 3.382402476477939 Job2-3 is being served
# The number of using resources is 1
# 3.6364799087712116 Job1-5 arrives
# Job1-5 is waiting
# 3.6364799087712116 Job1-5 is being served
# The number of using resources is 2
# 3.7703092321687874 Job1-5 finishes
# 3.8875915024122945 Job1-6 arrives
# Job1-6 is waiting
# 3.8875915024122945 Job1-6 is being served
# The number of using resources is 2
# 3.9196505799403085 Job1-7 arrives
# Job1-7 is waiting
# 3.928153189974672 Job1-6 finishes
# 3.928153189974672 Job1-7 is being served
# The number of using resources is 2
# 4.010598555788832 Job2-4 arrives
# Job2-4 is waiting
# 4.108203766100497 Job2-5 arrives
# Job2-5 is waiting
# 4.276786321186627 Job2-3 finishes
# 4.276786321186627 Job2-4 is being served
# The number of using resources is 2
# 4.427016505043275 Job1-7 finishes
# 4.427016505043275 Job2-5 is being served
# The number of using resources is 2
# 4.48445324190864 Job2-5 finishes
# 4.564519050721293 Job2-4 finishes
# 4.656221608005983 Job1-8 arrives
# Job1-8 is waiting
# 4.656221608005983 Job1-8 is being served
# The number of using resources is 1
# 4.832337443926848 Job1-9 arrives
# Job1-9 is waiting
# 4.832337443926848 Job1-9 is being served
# The number of using resources is 2
# 4.865527836709767 Job2-6 arrives
# Job2-6 is waiting
# 4.8713077493572605 Job1-8 finishes
# 4.8713077493572605 Job2-6 is being served
# The number of using resources is 2
# 5.054253465831572 Job2-6 finishes
# 5.177669540506066 Job1-10 arrives
# Job1-10 is waiting
# 5.177669540506066 Job1-10 is being served
# The number of using resources is 2
# 5.407936598443749 Job2-7 arrives
# Job2-7 is waiting
# 5.421886577517086 Job1-9 finishes
# 5.421886577517086 Job2-7 is being served
# The number of using resources is 2
# 5.5808297642207485 Job2-8 arrives
# Job2-8 is waiting
# 5.717875828346726 Job1-10 finishes
# 5.717875828346726 Job2-8 is being served
# The number of using resources is 2
# 5.915822817629387 Job1-11 arrives
# Job1-11 is waiting
# 6.062224140911039 Job2-8 finishes
# 6.062224140911039 Job1-11 is being served
# The number of using resources is 2
# 6.084140355180514 Job1-12 arrives
# Job1-12 is waiting
# 6.1789604919787235 Job2-7 finishes
# 6.1789604919787235 Job1-12 is being served
# The number of using resources is 2
# 6.362202750865875 Job1-12 finishes
# 6.374417489122266 Job1-13 arrives
# Job1-13 is waiting
# 6.374417489122266 Job1-13 is being served
# The number of using resources is 2
# 6.378543266719067 Job2-9 arrives
# Job2-9 is waiting
# 6.504766321522155 Job1-11 finishes
# 6.504766321522155 Job2-9 is being served
# The number of using resources is 2
# 6.608306334479645 Job1-13 finishes
# 6.612437414348805 Job1-14 arrives
# Job1-14 is waiting
# 6.612437414348805 Job1-14 is being served
# The number of using resources is 2
# 6.646893058237884 Job2-9 finishes
# 6.725082995057317 Job1-14 finishes
# 8.388415118660413 Job1-15 arrives
# Job1-15 is waiting
# 8.388415118660413 Job1-15 is being served
# The number of using resources is 1
# 8.551096922910741 Job1-15 finishes
# 8.983480707211712 Job1-16 arrives
# Job1-16 is waiting
# 8.983480707211712 Job1-16 is being served
# The number of using resources is 1
# 9.017798106708048 Job1-16 finishes
# 9.137754002446052 Job2-10 arrives
# Job2-10 is waiting
# 9.137754002446052 Job2-10 is being served
# The number of using resources is 1
# 9.178842617705826 Job2-11 arrives
# Job2-11 is waiting
# 9.178842617705826 Job2-11 is being served
# The number of using resources is 2
# 9.266525027863324 Job2-10 finishes
# 9.297443102001722 Job1-17 arrives
# Job1-17 is waiting
# 9.297443102001722 Job1-17 is being served
# The number of using resources is 2
# 9.535163832303299 Job1-17 finishes
# 9.608976371812675 Job2-12 arrives
# Job2-12 is waiting
# 9.608976371812675 Job2-12 is being served
# The number of using resources is 2
# 9.699890258288779 Job2-11 finishes
# 9.877105858237595 Job2-12 finishes
# 10.493470870373272 Job2-13 arrives
# Job2-13 is waiting
# 10.493470870373272 Job2-13 is being served
# The number of using resources is 1
# 11.199795846902594 Job2-14 arrives
# Job2-14 is waiting
# 11.199795846902594 Job2-14 is being served
# The number of using resources is 2
# 11.280734108645625 Job2-13 finishes
# 11.535936335956952 Job2-14 finishes
# 12.033046260785788 Job1-18 arrives
# Job1-18 is waiting
# 12.033046260785788 Job1-18 is being served
# The number of using resources is 1
# 12.059754940969 Job1-19 arrives
# Job1-19 is waiting
# 12.059754940969 Job1-19 is being served
# The number of using resources is 2
# 12.107626012626987 Job1-19 finishes
# 12.182572492630884 Job1-18 finishes
# 12.386683315695208 Job1-20 arrives
# Job1-20 is waiting
# 12.386683315695208 Job1-20 is being served
# The number of using resources is 1
# 12.54798421290616 Job1-20 finishes
# 12.560945955667847 Job2-15 arrives
# Job2-15 is waiting
# 12.560945955667847 Job2-15 is being served
# The number of using resources is 1
# 12.662936735473517 Job2-16 arrives
# Job2-16 is waiting
# 12.662936735473517 Job2-16 is being served
# The number of using resources is 2
# 12.715918306646303 Job1-21 arrives
# Job1-21 is waiting
# 13.137550552147179 Job2-16 finishes
# 13.137550552147179 Job1-21 is being served
# The number of using resources is 2
# 13.153916811839103 Job1-22 arrives
# Job1-22 is waiting
# 13.29676139241883 Job1-21 finishes
# 13.29676139241883 Job1-22 is being served
# The number of using resources is 2
# 13.540860783836614 Job1-22 finishes
# 13.694376387728553 Job2-17 arrives
# Job2-17 is waiting
# 13.694376387728553 Job2-17 is being served
# The number of using resources is 2
# 13.924214723017393 Job2-18 arrives
# Job2-18 is waiting
# 14.02008677230432 Job2-15 finishes
# 14.02008677230432 Job2-18 is being served
# The number of using resources is 2
# 14.158402278488266 Job1-23 arrives
# Job1-23 is waiting
# 14.217532571982707 Job2-18 finishes
# 14.217532571982707 Job1-23 is being served
# The number of using resources is 2
# 14.271091300221244 Job1-23 finishes
# 14.93212263912249 Job2-17 finishes
# 15.30507878539606 Job1-24 arrives
# Job1-24 is waiting
# 15.30507878539606 Job1-24 is being served
# The number of using resources is 1
# 15.317451018470198 Job1-24 finishes
# 15.844684159707208 Job1-25 arrives
# Job1-25 is waiting
# 15.844684159707208 Job1-25 is being served
# The number of using resources is 1
# 15.993615818337632 Job1-26 arrives
# Job1-26 is waiting
# 15.993615818337632 Job1-26 is being served
# The number of using resources is 2
# 16.065276352367192 Job1-25 finishes
# 16.09179846743584 Job1-27 arrives
# Job1-27 is waiting
# 16.09179846743584 Job1-27 is being served
# The number of using resources is 2
# 16.19696685985033 Job1-27 finishes
# 16.46327240135345 Job1-28 arrives
# Job1-28 is waiting
# 16.46327240135345 Job1-28 is being served
# The number of using resources is 2
# 16.466978535204923 Job1-26 finishes
# 16.49610051513392 Job1-28 finishes
# 16.58187782214299 Job1-29 arrives
# Job1-29 is waiting
# 16.58187782214299 Job1-29 is being served
# The number of using resources is 1
# 16.650028648714542 Job1-29 finishes
# 16.791978022814394 Job1-30 arrives
# Job1-30 is waiting
# 16.791978022814394 Job1-30 is being served
# The number of using resources is 1
# 16.964045059031644 Job1-30 finishes
# 17.042310151273384 Job1-31 arrives
# Job1-31 is waiting
# 17.042310151273384 Job1-31 is being served
# The number of using resources is 1
# 17.36328621911706 Job1-31 finishes
# 17.974120249709035 Job2-19 arrives
# Job2-19 is waiting
# 17.974120249709035 Job2-19 is being served
# The number of using resources is 1
# 17.98867896785144 Job1-32 arrives
# Job1-32 is waiting
# 17.98867896785144 Job1-32 is being served
# The number of using resources is 2
# 18.090823010050986 Job1-32 finishes
# 18.452591241791442 Job2-20 arrives
# Job2-20 is waiting
# 18.452591241791442 Job2-20 is being served
# The number of using resources is 2
# 18.691296558118808 Job2-20 finishes
# 18.7489289369676 Job2-19 finishes
# 19.373460277668578 Job1-33 arrives
# Job1-33 is waiting
# 19.373460277668578 Job1-33 is being served
# The number of using resources is 1
# 19.436936460589813 Job1-33 finishes
# 19.809852659515744 Job1-34 arrives
# Job1-34 is waiting
# 19.809852659515744 Job1-34 is being served
# The number of using resources is 1
# 19.979106793944943 Job1-34 finishes
# 20.57764128772622 Job1-35 arrives
# Job1-35 is waiting
# 20.57764128772622 Job1-35 is being served
# The number of using resources is 1
# 20.881035104995053 Job1-36 arrives
# Job1-36 is waiting
# 20.881035104995053 Job1-36 is being served
# The number of using resources is 2
# 20.90550228487521 Job1-37 arrives
# Job1-37 is waiting
# 20.952512690085292 Job1-35 finishes
# 20.952512690085292 Job1-37 is being served
# The number of using resources is 2
# 20.959559812608383 Job2-21 arrives
# Job2-21 is waiting
# 21.050238342201723 Job1-37 finishes
# 21.050238342201723 Job2-21 is being served
# The number of using resources is 2
# 21.057921137508078 Job2-21 finishes
# 21.119820211142112 Job1-36 finishes
# 21.190873393360274 Job1-38 arrives
# Job1-38 is waiting
# 21.190873393360274 Job1-38 is being served
# The number of using resources is 1
# 21.21970531731752 Job1-39 arrives
# Job1-39 is waiting
# 21.21970531731752 Job1-39 is being served
# The number of using resources is 2
# 21.252504716420738 Job1-39 finishes
# 21.271495112370772 Job1-38 finishes
# 21.425983113744106 Job2-22 arrives
# Job2-22 is waiting
# 21.425983113744106 Job2-22 is being served
# The number of using resources is 1
# 21.515499758928858 Job2-23 arrives
# Job2-23 is waiting
# 21.515499758928858 Job2-23 is being served
# The number of using resources is 2
# 21.658566518125024 Job1-40 arrives
# Job1-40 is waiting
# 21.698866944793743 Job2-23 finishes
# 21.698866944793743 Job1-40 is being served
# The number of using resources is 2
# 21.91052655225744 Job2-24 arrives
# Job2-24 is waiting
# 21.935721509211845 Job2-22 finishes
# 21.935721509211845 Job2-24 is being served
# The number of using resources is 2
# 21.968819945340407 Job2-24 finishes
# 22.166536669980115 Job1-41 arrives
# Job1-41 is waiting
# 22.166536669980115 Job1-41 is being served
# The number of using resources is 2
# 22.18882745386651 Job2-25 arrives
# Job2-25 is waiting
# 22.280541555331077 Job1-40 finishes
# 22.280541555331077 Job2-25 is being served
# The number of using resources is 2
# 22.5283755858559 Job1-41 finishes
# 22.53348322864273 Job1-42 arrives
# Job1-42 is waiting
# 22.53348322864273 Job1-42 is being served
# The number of using resources is 2
# 22.562626777483853 Job1-42 finishes
# 22.66940830121192 Job2-25 finishes
# 24.081198648866735 Job2-26 arrives
# Job2-26 is waiting
# 24.081198648866735 Job2-26 is being served
# The number of using resources is 1
# 24.13533494801844 Job2-26 finishes
# 24.351702927582963 Job1-43 arrives
# Job1-43 is waiting
# 24.351702927582963 Job1-43 is being served
# The number of using resources is 1
# 24.75339789132461 Job1-44 arrives
# Job1-44 is waiting
# 24.75339789132461 Job1-44 is being served
# The number of using resources is 2
# 24.85158864965782 Job1-44 finishes
# 25.033127766290686 Job1-43 finishes
# 25.666705445778884 Job1-45 arrives
# Job1-45 is waiting
# 25.666705445778884 Job1-45 is being served
# The number of using resources is 1
# 26.13672538241463 Job1-45 finishes
# 26.501753784422206 Job1-46 arrives
# Job1-46 is waiting
# 26.501753784422206 Job1-46 is being served
# The number of using resources is 1
# 26.642607813945325 Job1-46 finishes
# 26.83259541502187 Job1-47 arrives
# Job1-47 is waiting
# 26.83259541502187 Job1-47 is being served
# The number of using resources is 1
# 27.16787482899146 Job2-27 arrives
# Job2-27 is waiting
# 27.16787482899146 Job2-27 is being served
# The number of using resources is 2
# 27.187243534629765 Job1-48 arrives
# Job1-48 is waiting
# 27.188742359497727 Job2-27 finishes
# 27.188742359497727 Job1-48 is being served
# The number of using resources is 2
# 27.194950052112436 Job1-47 finishes
# 27.40271559388856 Job2-28 arrives
# Job2-28 is waiting
# 27.40271559388856 Job2-28 is being served
# The number of using resources is 2
# 27.819073128929443 Job2-28 finishes
# 27.82344693505698 Job1-49 arrives
# Job1-49 is waiting
# 27.82344693505698 Job1-49 is being served
# The number of using resources is 2
# 27.829960036518216 Job1-49 finishes
# 27.89945190197067 Job1-48 finishes
# 28.086576397352545 Job1-50 arrives
# Job1-50 is waiting
# 28.086576397352545 Job1-50 is being served
# The number of using resources is 1
# 28.183364094751457 Job1-50 finishes
# 29.339462153423547 Job2-29 arrives
# Job2-29 is waiting
# 29.339462153423547 Job2-29 is being served
# The number of using resources is 1
# 29.469987399947097 Job2-30 arrives
# Job2-30 is waiting
# 29.469987399947097 Job2-30 is being served
# The number of using resources is 2
# 29.68019697672879 Job2-29 finishes
# 29.686550838415098 Job2-30 finishes
# 30.409223923610995 Job1-51 arrives
# Job1-51 is waiting
# 30.409223923610995 Job1-51 is being served
# The number of using resources is 1
# 30.467197569359318 Job1-52 arrives
# Job1-52 is waiting
# 30.467197569359318 Job1-52 is being served
# The number of using resources is 2
# 30.53925288491745 Job1-52 finishes
# 30.637567237968963 Job1-53 arrives
# Job1-53 is waiting
# 30.637567237968963 Job1-53 is being served
# The number of using resources is 2
# 30.731013827162386 Job1-53 finishes
# 30.846072641691546 Job1-51 finishes
# 31.36676168117835 Job1-54 arrives
# Job1-54 is waiting
# 31.36676168117835 Job1-54 is being served
# The number of using resources is 1
# 31.391652956385542 Job1-54 finishes
# 31.429774657259202 Job2-31 arrives
# Job2-31 is waiting
# 31.429774657259202 Job2-31 is being served
# The number of using resources is 1
# 31.68373009698783 Job2-31 finishes
# 31.728839889514756 Job1-55 arrives
# Job1-55 is waiting
# 31.728839889514756 Job1-55 is being served
# The number of using resources is 1
# 31.82405676565831 Job1-55 finishes
# 32.427711997754784 Job2-32 arrives
# Job2-32 is waiting
# 32.427711997754784 Job2-32 is being served
# The number of using resources is 1
# 32.58822811057881 Job1-56 arrives
# Job1-56 is waiting
# 32.58822811057881 Job1-56 is being served
# The number of using resources is 2
# 32.60177405926575 Job2-33 arrives
# Job2-33 is waiting
# 32.60432683201565 Job1-56 finishes
# 32.60432683201565 Job2-33 is being served
# The number of using resources is 2
# 32.63932679282398 Job2-32 finishes
# 32.65900168911664 Job2-33 finishes
# 32.75062429365811 Job1-57 arrives
# Job1-57 is waiting
# 32.75062429365811 Job1-57 is being served
# The number of using resources is 1
# 32.90526972388657 Job2-34 arrives
# Job2-34 is waiting
# 32.90526972388657 Job2-34 is being served
# The number of using resources is 2
# 33.08317842512594 Job1-58 arrives
# Job1-58 is waiting
# 33.30420633722713 Job2-34 finishes
# 33.30420633722713 Job1-58 is being served
# The number of using resources is 2
# 33.378158236392636 Job1-58 finishes
# 33.38065093347869 Job2-35 arrives
# Job2-35 is waiting
# 33.38065093347869 Job2-35 is being served
# The number of using resources is 2
# 33.38793558651344 Job1-59 arrives
# Job1-59 is waiting
# 33.42655516525432 Job2-36 arrives
# Job2-36 is waiting
# 33.48792014624912 Job1-57 finishes
# 33.48792014624912 Job1-59 is being served
# The number of using resources is 2
# 33.652785122453324 Job2-35 finishes
# 33.652785122453324 Job2-36 is being served
# The number of using resources is 2
# 33.715635217589075 Job1-59 finishes
# 33.790386108114284 Job2-37 arrives
# Job2-37 is waiting
# 33.790386108114284 Job2-37 is being served
# The number of using resources is 2
# 33.7909681344323 Job2-36 finishes
# 33.79468535170468 Job1-60 arrives
# Job1-60 is waiting
# 33.79468535170468 Job1-60 is being served
# The number of using resources is 2
# 34.1276299472002 Job1-60 finishes
# 34.311163924023354 Job1-61 arrives
# Job1-61 is waiting
# 34.311163924023354 Job1-61 is being served
# The number of using resources is 2
# 34.68118897850285 Job2-37 finishes
# 35.1074294988636 Job1-61 finishes
# 35.16540879478343 Job2-38 arrives
# Job2-38 is waiting
# 35.16540879478343 Job2-38 is being served
# The number of using resources is 1
# 35.507321462475524 Job1-62 arrives
# Job1-62 is waiting
# 35.507321462475524 Job1-62 is being served
# The number of using resources is 2
# 35.55520509807071 Job1-62 finishes
# 35.67555998873332 Job2-39 arrives
# Job2-39 is waiting
# 35.67555998873332 Job2-39 is being served
# The number of using resources is 2
# 35.715316910383805 Job1-63 arrives
# Job1-63 is waiting
# 35.72411874491069 Job2-38 finishes
# 35.72411874491069 Job1-63 is being served
# The number of using resources is 2
# 35.9372062015596 Job1-63 finishes
# 35.981669590690345 Job2-39 finishes
# 36.08805170450844 Job2-40 arrives
# Job2-40 is waiting
# 36.08805170450844 Job2-40 is being served
# The number of using resources is 1
# 36.11960230945523 Job2-40 finishes
# 36.781492003643955 Job1-64 arrives
# Job1-64 is waiting
# 36.781492003643955 Job1-64 is being served
# The number of using resources is 1
# 37.54811358434378 Job1-64 finishes
# 37.77483613810355 Job2-41 arrives
# Job2-41 is waiting
# 37.77483613810355 Job2-41 is being served
# The number of using resources is 1
# 37.809295726171136 Job1-65 arrives
# Job1-65 is waiting
# 37.809295726171136 Job1-65 is being served
# The number of using resources is 2
# 37.862344032985106 Job2-42 arrives
# Job2-42 is waiting
# 38.056257846471496 Job1-65 finishes
# 38.056257846471496 Job2-42 is being served
# The number of using resources is 2
# 38.12879983980161 Job2-41 finishes
# 38.150990240800475 Job1-66 arrives
# Job1-66 is waiting
# 38.150990240800475 Job1-66 is being served
# The number of using resources is 2
# 38.16278179690794 Job2-42 finishes
# 38.19538463823999 Job1-66 finishes
# 38.27762440611145 Job2-43 arrives
# Job2-43 is waiting
# 38.27762440611145 Job2-43 is being served
# The number of using resources is 1
# 38.28451924752691 Job1-67 arrives
# Job1-67 is waiting
# 38.28451924752691 Job1-67 is being served
# The number of using resources is 2
# 38.288706892068376 Job1-67 finishes
# 38.46597055241436 Job1-68 arrives
# Job1-68 is waiting
# 38.46597055241436 Job1-68 is being served
# The number of using resources is 2
# 38.553789986335644 Job1-69 arrives
# Job1-69 is waiting
# 38.84309378639447 Job1-68 finishes
# 38.84309378639447 Job1-69 is being served
# The number of using resources is 2
# 38.87403860276964 Job1-69 finishes
# 38.89692410454629 Job2-43 finishes
# 39.093623626500204 Job1-70 arrives
# Job1-70 is waiting
# 39.093623626500204 Job1-70 is being served
# The number of using resources is 1
# 39.1075821521764 Job1-71 arrives
# Job1-71 is waiting
# 39.1075821521764 Job1-71 is being served
# The number of using resources is 2
# 39.1538011206634 Job1-70 finishes
# 39.53507673050656 Job1-72 arrives
# Job1-72 is waiting
# 39.53507673050656 Job1-72 is being served
# The number of using resources is 2
# 39.704158872484435 Job1-72 finishes
# 39.903763721289764 Job1-71 finishes
# 39.985892194533825 Job2-44 arrives
# Job2-44 is waiting
# 39.985892194533825 Job2-44 is being served
# The number of using resources is 1
# 40.03317483658401 Job2-44 finishes
# 40.06386921744708 Job1-73 arrives
# Job1-73 is waiting
# 40.06386921744708 Job1-73 is being served
# The number of using resources is 1
# 40.17862567190697 Job1-73 finishes
# 40.538900088968894 Job2-45 arrives
# Job2-45 is waiting
# 40.538900088968894 Job2-45 is being served
# The number of using resources is 1
# 40.5539701799883 Job2-46 arrives
# Job2-46 is waiting
# 40.5539701799883 Job2-46 is being served
# The number of using resources is 2
# 40.998720494361535 Job2-46 finishes
# 41.00683007617828 Job1-74 arrives
# Job1-74 is waiting
# 41.00683007617828 Job1-74 is being served
# The number of using resources is 2
# 41.38390688829181 Job1-74 finishes
# 41.86346984363538 Job2-45 finishes
# 41.87968223304668 Job1-75 arrives
# Job1-75 is waiting
# 41.87968223304668 Job1-75 is being served
# The number of using resources is 1
# 41.992410697591716 Job1-75 finishes
# 42.18851359555321 Job1-76 arrives
# Job1-76 is waiting
# 42.18851359555321 Job1-76 is being served
# The number of using resources is 1
# 42.30661192319926 Job1-76 finishes
# 43.21835147144833 Job2-47 arrives
# Job2-47 is waiting
# 43.21835147144833 Job2-47 is being served
# The number of using resources is 1
# 43.594746849778424 Job1-77 arrives
# Job1-77 is waiting
# 43.594746849778424 Job1-77 is being served
# The number of using resources is 2
# 43.82522595647736 Job1-78 arrives
# Job1-78 is waiting
# 43.87926708498382 Job1-77 finishes
# 43.87926708498382 Job1-78 is being served
# The number of using resources is 2
# 44.12024860544641 Job1-79 arrives
# Job1-79 is waiting
# 44.2608835409736 Job1-80 arrives
# Job1-80 is waiting
# 44.275299448698476 Job1-81 arrives
# Job1-81 is waiting
# 44.38719048299122 Job1-82 arrives
# Job1-82 is waiting
# 44.43536370958945 Job1-83 arrives
# Job1-83 is waiting
# 44.45966571047752 Job1-78 finishes
# 44.45966571047752 Job1-79 is being served
# The number of using resources is 2
# 44.50322898181296 Job1-79 finishes
# 44.50322898181296 Job1-80 is being served
# The number of using resources is 2
# 44.834937269513254 Job1-84 arrives
# Job1-84 is waiting
# 44.887099737603805 Job2-47 finishes
# 44.887099737603805 Job1-81 is being served
# The number of using resources is 2
# 44.95280256128447 Job1-80 finishes
# 44.95280256128447 Job1-82 is being served
# The number of using resources is 2
# 45.00769292102238 Job1-81 finishes
# 45.00769292102238 Job1-83 is being served
# The number of using resources is 2
# 45.06775199419892 Job1-82 finishes
# 45.06775199419892 Job1-84 is being served
# The number of using resources is 2
# 45.18133563179901 Job1-83 finishes
# 45.26312865970725 Job1-85 arrives
# Job1-85 is waiting
# 45.26312865970725 Job1-85 is being served
# The number of using resources is 2
# 45.288120560083144 Job1-84 finishes
# 45.59100131897719 Job1-86 arrives
# Job1-86 is waiting
# 45.59100131897719 Job1-86 is being served
# The number of using resources is 2
# 45.60940140669558 Job1-86 finishes
# 45.63626832294473 Job1-85 finishes
# 45.749671374511756 Job1-87 arrives
# Job1-87 is waiting
# 45.749671374511756 Job1-87 is being served
# The number of using resources is 1
# 45.88205871198348 Job1-88 arrives
# Job1-88 is waiting
# 45.88205871198348 Job1-88 is being served
# The number of using resources is 2
# 46.01384867864203 Job1-87 finishes
# 46.069599236149706 Job2-48 arrives
# Job2-48 is waiting
# 46.069599236149706 Job2-48 is being served
# The number of using resources is 2
# 46.151356762905316 Job2-48 finishes
# 46.25741187700343 Job2-49 arrives
# Job2-49 is waiting
# 46.25741187700343 Job2-49 is being served
# The number of using resources is 2
# 46.464784925452875 Job2-49 finishes
# 46.70486057776925 Job1-89 arrives
# Job1-89 is waiting
# 46.70486057776925 Job1-89 is being served
# The number of using resources is 2
# 46.873447091101006 Job1-89 finishes
# 47.011815976017445 Job2-50 arrives
# Job2-50 is waiting
# 47.011815976017445 Job2-50 is being served
# The number of using resources is 2
# 47.098725315101525 Job2-50 finishes
# 47.419874020566695 Job1-90 arrives
# Job1-90 is waiting
# 47.419874020566695 Job1-90 is being served
# The number of using resources is 2
# 47.548145480117405 Job1-90 finishes
# 48.052876273492636 Job1-88 finishes
# 48.19252547792819 Job1-91 arrives
# Job1-91 is waiting
# 48.19252547792819 Job1-91 is being served
# The number of using resources is 1
# 48.294298823533154 Job1-91 finishes
# 48.63375166644831 Job1-92 arrives
# Job1-92 is waiting
# 48.63375166644831 Job1-92 is being served
# The number of using resources is 1
# 48.73435091293886 Job2-51 arrives
# Job2-51 is waiting
# 48.73435091293886 Job2-51 is being served
# The number of using resources is 2
# 48.735369346520606 Job1-93 arrives
# Job1-93 is waiting
# 48.737510717546506 Job1-94 arrives
# Job1-94 is waiting
# 48.78653587882081 Job1-92 finishes
# 48.78653587882081 Job1-93 is being served
# The number of using resources is 2
# 48.79066214745567 Job2-51 finishes
# 48.79066214745567 Job1-94 is being served
# The number of using resources is 2
# 48.80126479665246 Job1-94 finishes
# 48.98947638963999 Job1-93 finishes
# 49.17133564774145 Job1-95 arrives
# Job1-95 is waiting
# 49.17133564774145 Job1-95 is being served
# The number of using resources is 1
# 49.23208531358036 Job1-96 arrives
# Job1-96 is waiting
# 49.23208531358036 Job1-96 is being served
# The number of using resources is 2
# 49.253385859028626 Job1-96 finishes
# 49.30882651728921 Job1-95 finishes
# 49.582256115568825 Job1-97 arrives
# Job1-97 is waiting
# 49.582256115568825 Job1-97 is being served
# The number of using resources is 1
# 49.60574373070596 Job1-97 finishes
# 49.684006209924156 Job1-98 arrives
# Job1-98 is waiting
# 49.684006209924156 Job1-98 is being served
# The number of using resources is 1
# 49.761286368673595 Job1-99 arrives
# Job1-99 is waiting
# 49.761286368673595 Job1-99 is being served
# The number of using resources is 2
# 49.81097387802986 Job1-100 arrives
# Job1-100 is waiting
